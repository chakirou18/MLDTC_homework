# %%
#1.Pandas version
pd.__version__
# Out:
# '3.0.5'

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv')

# %%
#loading dataframe
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# 4          17.5                 31.0

# %%
#2.Records count:How many records are in the dataset?
df.shape
# Out:
# (10000, 11)

# %%
#3.Fuel types:How many fuel types are presented in the dataset?
df['fuel_type'].nunique()
# Out:
# 3

# %%
#4.Missing values:How many columns in the dataset have missing values?
df.isna().any().sum()
# Out:
# np.int64(2)

# %%
#5.Max fuel efficiency:What's the maximum fuel efficiency of cars from Asia?
df.loc[df["origin"]=="Asia","fuel_efficiency_mpg"].max()
# Out:
# np.float64(41.2)

# %%
#6.Median value of horsepower
#6.1.Find the median value of the horsepower column in the dataset.
df["horsepower"].median()
# Out:
# np.float64(254.0)

# %%
#6.2.Next, calculate the most frequent value of the same horsepower column.
most_frequent = df["horsepower"].mode()[0]
most_frequent
# Out:
# np.float64(252.0)

# %%
#6.3.Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
df["horsepower"]= df["horsepower"].fillna(most_frequent)
#6.4.Now, calculate the median value of horsepower once again.
df["horsepower"].median()
# Out:
# np.float64(252.0)

# %%
#7.Sum of weights
#7.1.Select all the cars from Asia
asia_cars = df[df["origin"] == "Asia"]
#7.2.Select only columns vehicle_weight and model_year
asia_cars = asia_cars[["vehicle_weight","model_year"]]
#7.3.Select the first 7 values
asia_cars = asia_cars.head(7)
#7.4.Get the underlying NumPy array. Let's call it X.
X = asia_cars.values
#7.5.Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
XTX= X.T @ X
#7.6.Invert XTX.
XTX_inv = np.linalg.inv(XTX)

# %%
#7.7.Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
#7.8. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
w = XTX_inv @ X.T @ y

# %%
#7.9.What's the sum of all the elements of the result?
w.sum()
# Out:
# np.float64(0.36919696904925486)
